# %%
# !pip install konlpy
# !pip install pandas numpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 3.5 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# ...
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# ...

# %%
import time
from konlpy import tag
from konlpy.corpus import kolaw
from konlpy.utils import pprint
from konlpy.tag import Okt
from collections import Counter

import pandas as pd
import re
import konlpy
konlpy.data.path
# Out:
# ['/Users/lora/konlpy_data',
#  '/usr/share/konlpy_data',
#  '/usr/local/share/konlpy_data',
#  '/usr/lib/konlpy_data',
#  '/usr/local/lib/konlpy_data',
#  '/opt/homebrew/anaconda3/envs/okt/lib/python3.10/site-packages/konlpy/data']

# %%
okt = Okt()
print(okt.pos(u'K8S입니다 초대졸이상 Vue.js하실 수 있는 분 프론트엔드 서비스 개발 경험 RESTAPI사용해요 C#, C++경험자, HTML5에 대한 지식'))
# Out:
# [('K', 'Alpha'), ('8', 'Number'), ('S', 'Alpha'), ('입니다', 'Adjective'), ('초대', 'Noun'), ('졸', 'Noun'), ('이상', 'Noun'), ('Vue', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha'), ('하실', 'Verb'), ('수', 'Noun'), ('있는', 'Adjective'), ('분', 'Noun'), ('프론트엔드', 'Noun'), ('서비스', 'Noun'), ('개발', 'Noun'), ('경험', 'Noun'), ('RESTAPI', 'Alpha'), ('사용', 'Noun'), ('해요', 'Verb'), ('C', 'Alpha'), ('#,', 'Punctuation'), ('C', 'Alpha'), ('++', 'Punctuation'), ('경험', 'Noun'), ('자', 'Suffix'), (',', 'Punctuation'), ('HTML', 'Alpha'), ('5', 'Number'), ('에', 'Josa'), ('대한', 'Noun'), ('지식', 'Noun')]

# %% [markdown]
# # noun 사용자 사전 편집

# %%
# java 경로 확인 후 압축 해제
import os

os.chdir('/opt/homebrew/anaconda3/envs/okt/lib/python3.10/site-packages/konlpy/java')
os.getcwd() 
#원본 경로에 있는 open-korean-text-2.10.jar 파일은 따로 백업해주세요!
# !jar xvf open-korean-text-2.1.0.jar
# Out:
#   created: META-INF/
#  inflated: META-INF/MANIFEST.MF
#   created: org/
#   created: org/openkoreantext/
#   created: org/openkoreantext/processor/
#   created: org/openkoreantext/processor/normalizer/
#   created: org/openkoreantext/processor/phrase_extractor/
#   created: org/openkoreantext/processor/qa/
#   created: org/openkoreantext/processor/stemmer/
#   created: org/openkoreantext/processor/tokenizer/
#   created: org/openkoreantext/processor/tools/
#   created: org/openkoreantext/processor/util/
#   created: org/openkoreantext/processor/util/adjective/
#   created: org/openkoreantext/processor/util/adverb/
#   created: org/openkoreantext/processor/util/auxiliary/
#   created: org/openkoreantext/processor/util/freq/
#   created: org/openkoreantext/processor/util/josa/
#   created: org/openkoreantext/processor/util/noun/
#   created: org/openkoreantext/processor/util/substantives/
#   created: org/openkoreantext/processor/util/typos/
# ...

# %%
# noun(명사) 중에서 names.txt 파일을 열어서 okt 사전에 정의되어 있는 단어 50개 확인
with open(f"/opt/homebrew/anaconda3/envs/okt/lib/python3.10/site-packages/konlpy/java/org/openkoreantext/processor/util/noun/names.txt") as f:
    data = f.read()
    
print(data[:50])
# Out:
# 가몽
# 가온
# 갓세븐
# 강새이
# 게임닉가
# 관우
# 귀여미
# 규
# 김유이
# 김준면
# 까까런
# 노컷
# 누너예
# 니노

# %%
#새롭게 정의할 사용자 사전 추가
data += 'K8S\n초대졸\nVue.js\n프론트엔드 서비스\nRESTAPI\nC#\nC++\nHTML5\n'

# %%
#수정된 name.txt 저장 후 jar 압축
with open("/opt/homebrew/anaconda3/envs/okt/lib/python3.10/site-packages/konlpy/java/org/openkoreantext/processor/util/noun/names.txt", 'w') as f:
    f.write(data)
    
# !jar cvf open-korean-text-2.1.0.jar org
# Out:
# added manifest
# adding: org/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/KoreanPosJava.class(in = 2457) (out= 1241)(deflated 49%)
# adding: org/openkoreantext/processor/KoreanTokenJava.class(in = 1976) (out= 931)(deflated 52%)
# adding: org/openkoreantext/processor/OpenKoreanTextProcessor$.class(in = 7716) (out= 2400)(deflated 68%)
# adding: org/openkoreantext/processor/OpenKoreanTextProcessor.class(in = 4428) (out= 1997)(deflated 54%)
# adding: org/openkoreantext/processor/OpenKoreanTextProcessorJava.class(in = 5901) (out= 1995)(deflated 66%)
# adding: org/openkoreantext/processor/normalizer/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/normalizer/KoreanNormalizer$.class(in = 11553) (out= 5102)(deflated 55%)
# ...

# %%
#다시 Okt import 후 실험
from konlpy.tag import Okt
okt = Okt()
print(okt.pos(u'K8S입니다 초대졸이상 Vue.js하실 수 있는 분 프론트엔드 서비스 개발 경험 RESTAPI사용해요 C#, C++경험자, HTML5에 대한 지식'))
# Out:
# [('K', 'Alpha'), ('8', 'Number'), ('S', 'Alpha'), ('입니다', 'Adjective'), ('초대졸', 'Noun'), ('이상', 'Noun'), ('Vue', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha'), ('하실', 'Verb'), ('수', 'Noun'), ('있는', 'Adjective'), ('분', 'Noun'), ('프론트엔드', 'Noun'), ('서비스', 'Noun'), ('개발', 'Noun'), ('경험', 'Noun'), ('RESTAPI', 'Alpha'), ('사용', 'Noun'), ('해요', 'Verb'), ('C', 'Alpha'), ('#,', 'Punctuation'), ('C', 'Alpha'), ('++', 'Punctuation'), ('경험', 'Noun'), ('자', 'Suffix'), (',', 'Punctuation'), ('HTML', 'Alpha'), ('5', 'Number'), ('에', 'Josa'), ('대한', 'Noun'), ('지식', 'Noun')]

# %%
print(okt.pos(u'K8S 초대졸 Vue.js 프론트엔드 서비스 RESTAPI C# C++ HTML5'))
# Out:
# [('K', 'Alpha'), ('8', 'Number'), ('S', 'Alpha'), ('초대졸', 'Noun'), ('Vue', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha'), ('프론트엔드', 'Noun'), ('서비스', 'Noun'), ('RESTAPI', 'Alpha'), ('C', 'Alpha'), ('#', 'Punctuation'), ('C', 'Alpha'), ('++', 'Punctuation'), ('HTML', 'Alpha'), ('5', 'Number')]

# %%
# 사전 등록 전
[('K', 'Alpha'), ('8', 'Number'), ('S', 'Alpha'), ('초대', 'Noun'), ('졸', 'Noun'), ('Vue', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha'), ('프론트엔드', 'Noun'), ('서비스', 'Noun'), ('RESTAPI', 'Alpha'), ('C', 'Alpha'), ('#,', 'Punctuation'), ('C', 'Alpha'), ('++', 'Punctuation'),  ('HTML', 'Alpha'), ('5', 'Number')]

# 사전 등록 후
[('K', 'Alpha'), ('8', 'Number'), ('S', 'Alpha'),  ('초대졸', 'Noun'), ('Vue', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha'), ('프론트엔드', 'Noun'), ('서비스', 'Noun'),  ('RESTAPI', 'Alpha'),  ('C', 'Alpha'), ('#,', 'Punctuation'), ('C', 'Alpha'), ('++', 'Punctuation'), ('HTML', 'Alpha'), ('5', 'Number')]

# %% [markdown]
# # foreign 사용자 사전 편집

# %%
# 외국어 사전을 편집해서 재시도
# java 경로 확인 후 압축 해제
import os

os.chdir('/opt/homebrew/anaconda3/envs/okt/lib/python3.10/site-packages/konlpy/java')
os.getcwd() 
#원본 경로에 있는 open-korean-text-2.10.jar 파일은 따로 백업해주세요!
# !jar xvf open-korean-text-2.1.0.jar

# noun(명사) 중에서 names.txt 파일을 열어서 okt 사전에 정의되어 있는 단어 50개 확인
with open(f"/opt/homebrew/anaconda3/envs/okt/lib/python3.10/site-packages/konlpy/java/org/openkoreantext/processor/util/noun/foreign.txt") as f:
    data = f.read()
    
print(data[:50])
# Out:
#   created: META-INF/
#  inflated: META-INF/MANIFEST.MF
#   created: org/
#   created: org/openkoreantext/
#   created: org/openkoreantext/processor/
#  inflated: org/openkoreantext/processor/KoreanPosJava.class
#  inflated: org/openkoreantext/processor/KoreanTokenJava.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessor$.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessor.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessorJava.class
#   created: org/openkoreantext/processor/normalizer/
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment$.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer.class
#   created: org/openkoreantext/processor/phrase_extractor/
# ...

# %%
#새롭게 정의할 사용자 사전 추가
data += 'K8S\nVue.js\nRESTAPI\nC#\nC++\nHTML5\n'

# %%
#수정된 name.txt 저장 후 jar 압축
with open("/opt/homebrew/anaconda3/envs/okt/lib/python3.10/site-packages/konlpy/java/org/openkoreantext/processor/util/noun/foreign.txt", 'w') as f:
    f.write(data)
    
# !jar cvf open-korean-text-2.1.0.jar org
# Out:
# added manifest
# adding: org/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/KoreanPosJava.class(in = 2457) (out= 1241)(deflated 49%)
# adding: org/openkoreantext/processor/KoreanTokenJava.class(in = 1976) (out= 931)(deflated 52%)
# adding: org/openkoreantext/processor/OpenKoreanTextProcessor$.class(in = 7716) (out= 2400)(deflated 68%)
# adding: org/openkoreantext/processor/OpenKoreanTextProcessor.class(in = 4428) (out= 1997)(deflated 54%)
# adding: org/openkoreantext/processor/OpenKoreanTextProcessorJava.class(in = 5901) (out= 1995)(deflated 66%)
# adding: org/openkoreantext/processor/normalizer/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/normalizer/KoreanNormalizer$.class(in = 11553) (out= 5102)(deflated 55%)
# ...

# %%
#다 닫고 다시 Okt import 후 실험
from konlpy.tag import Okt
okt = Okt()
print(okt.pos(u'K8S 초대졸 Vue.js 프론트엔드 서비스 RESTAPI C# C++ HTML5'))
# Out:
# [('K', 'Alpha'), ('8', 'Number'), ('S', 'Alpha'), ('초대졸', 'Noun'), ('Vue', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha'), ('프론트엔드', 'Noun'), ('서비스', 'Noun'), ('RESTAPI', 'Alpha'), ('C', 'Alpha'), ('#', 'Punctuation'), ('C', 'Alpha'), ('++', 'Punctuation'), ('HTML', 'Alpha'), ('5', 'Number')]

# %%
[('K', 'Alpha'), ('8', 'Number'), ('S', 'Alpha'), ('초대졸', 'Noun'), ('Vue', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha'), ('프론트엔드', 'Noun'), ('서비스', 'Noun'), ('RESTAPI', 'Alpha'), ('C', 'Alpha'), ('#', 'Punctuation'), ('C', 'Alpha'), ('++', 'Punctuation'), ('HTML', 'Alpha'), ('5', 'Number')]

# %%
#다 닫고 다시 Okt import 후 실험
from konlpy.tag import Okt
okt = Okt()
print(okt.pos(u'k8s 초대졸 vue.js 프론트엔드 서비스 restapi c# c++ html5'))
# Out:
# [('k', 'Alpha'), ('8', 'Number'), ('s', 'Alpha'), ('초대졸', 'Noun'), ('vue', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha'), ('프론트엔드', 'Noun'), ('서비스', 'Noun'), ('restapi', 'Alpha'), ('c', 'Alpha'), ('#', 'Punctuation'), ('c', 'Alpha'), ('++', 'Punctuation'), ('html', 'Alpha'), ('5', 'Number')]

# %% [markdown]
# # 소문자로 noun 사용자 사전 편집

# %%
# java 경로 확인 후 압축 해제
import os

os.chdir('/opt/homebrew/anaconda3/envs/okt/lib/python3.10/site-packages/konlpy/java')
os.getcwd() 

# !jar xvf open-korean-text-2.1.0.jar

# noun(명사) 중에서 names.txt 파일을 열어서 okt 사전에 정의되어 있는 단어 50개 확인
with open(f"/opt/homebrew/anaconda3/envs/okt/lib/python3.10/site-packages/konlpy/java/org/openkoreantext/processor/util/noun/names.txt") as f:
    data = f.read()

#새롭게 정의할 사용자 사전 추가
data += 'k8s\nvue.js\nrestapi\nc#\nc++\nhtml5\n'

#수정된 name.txt 저장 후 jar 압축
with open("/opt/homebrew/anaconda3/envs/okt/lib/python3.10/site-packages/konlpy/java/org/openkoreantext/processor/util/noun/names.txt", 'w') as f:
    f.write(data)
    
# !jar cvf open-korean-text-2.1.0.jar org
# Out:
#   created: META-INF/
#  inflated: META-INF/MANIFEST.MF
#   created: org/
#   created: org/openkoreantext/
#   created: org/openkoreantext/processor/
#  inflated: org/openkoreantext/processor/KoreanPosJava.class
#  inflated: org/openkoreantext/processor/KoreanTokenJava.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessor$.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessor.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessorJava.class
#   created: org/openkoreantext/processor/normalizer/
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment$.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer.class
#   created: org/openkoreantext/processor/phrase_extractor/
# ...

# %%
#다 닫고 다시 Okt import 후 실험
from konlpy.tag import Okt
okt = Okt()
print(okt.pos(u'k8s 초대졸 vue.js 프론트엔드 서비스 restapi c# c++ html5'))
# Out:
# [('k', 'Alpha'), ('8', 'Number'), ('s', 'Alpha'), ('초대졸', 'Noun'), ('vue', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha'), ('프론트엔드', 'Noun'), ('서비스', 'Noun'), ('restapi', 'Alpha'), ('c', 'Alpha'), ('#', 'Punctuation'), ('c', 'Alpha'), ('++', 'Punctuation'), ('html', 'Alpha'), ('5', 'Number')]

# %%
# noun(명사) 중에서 names.txt 파일을 열어서 okt 사전에 정의되어 있는 단어 50개 확인
with open(f"/opt/homebrew/anaconda3/envs/okt/lib/python3.10/site-packages/konlpy/java/org/openkoreantext/processor/util/noun/twitter.txt") as f:
    data = f.read()
    
print(data[:50])
# Out:
# 계이
# 계폭
# 답멘
# 디엠
# 리튓
# 리트윗
# 맞팔
# 멘션
# 본계
# 봇
# 봇주
# 블언블
# 선팔
# 실트
# 인멘
# 친추
# 탐
