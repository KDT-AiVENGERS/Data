# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/horya/git/AIInfra/data/pre_result.csv')

df.head(1)
# Out:
#     회사명                         공고명   직무내용  \
# 0  혜움랩스  Python Developer (백엔드 주니어)  웹 개발자
#
#                                                 자격요건  \
# 0  • 최소 2년 이상 혹은 그에 준하는 해당 업무 경험\r\n• Python(필수),...
#
#                                                 우대조건  경력조건  \
# 0  • MSA 기반의 시스템 개발 경험이 있으신 분\r\n• AWS 를 활용한 개발, ...     2
#
#                                출처 URL  \
# 0  https://www.wanted.co.kr/wd/167436
#
#                                                   복지  \
# 0  # 몰입을 위한\r\n• 액면가 스톡옵션의 기회가 열려있습니다. (2023년 7월 ...
#
#                                                 회사소개  \
# 0  - 간단소개\r\n혜움랩스는 세무,재무,경리 등 AI기반 비서형 금융 서비스를 Fa...
#
#                                                 주요업무
# 0  • 세무 알고리즘 자동화 설계 및 개발\r\n• 세무팀과 커뮤니케이션\r\n• AW...

# %%
urls = ['https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1252097',
        'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1250832',
        'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1249135',
        'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1243455',
        'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1252062',
        'https://www.wanted.co.kr/wd/155658',
        'https://www.wanted.co.kr/wd/155658',
        'https://www.wanted.co.kr/wd/163673',
        'https://www.wanted.co.kr/wd/148349',
        'https://www.wanted.co.kr/wd/167433',
        'https://www.wanted.co.kr/wd/163886',
        'https://www.wanted.co.kr/wd/161960',
        'https://www.wanted.co.kr/wd/161305',
        'https://www.wanted.co.kr/wd/163769',
        'https://www.jumpit.co.kr/position/4204',
        'https://www.jumpit.co.kr/position/4204',
        'https://www.jumpit.co.kr/position/4204',
        'https://www.wanted.co.kr/wd/161585',
        'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1247596',
        'https://www.wanted.co.kr/wd/164601',
        'https://www.wanted.co.kr/wd/97166',
        'https://www.jumpit.co.kr/position/13082',
        'https://www.jumpit.co.kr/position/12965',
        'https://www.wanted.co.kr/wd/161835',
        'https://www.jumpit.co.kr/position/11036',
        'https://www.jumpit.co.kr/position/14411',
        'https://www.wanted.co.kr/wd/161835',
        'https://www.wanted.co.kr/wd/140496',
        'https://www.wanted.co.kr/wd/152935',
        'https://www.wanted.co.kr/wd/160748',
        'https://www.wanted.co.kr/wd/144525',
        'https://www.wanted.co.kr/wd/159587',
        'https://www.wanted.co.kr/wd/158350',
        'https://www.wanted.co.kr/wd/166305',
        'https://www.wanted.co.kr/wd/76590',
        'https://www.wanted.co.kr/wd/155823',
        'https://www.wanted.co.kr/wd/90288',
        'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1252157',
        'https://www.wanted.co.kr/wd/86496',
        'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1248932',
        'https://www.wanted.co.kr/wd/75640',
        'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1250043',
        'https://www.wanted.co.kr/wd/143022',
        'https://www.wanted.co.kr/wd/163197']

# %%
pd.set_option('display.max_colwidth', None)

# %%
df[df['공고명'] == '3D 그래픽스 엔지니어']['출처 URL']
# Out:
# 2323                                  https://www.wanted.co.kr/wd/155383
# 7774                                  https://www.wanted.co.kr/wd/155383
# 7868                                  https://www.wanted.co.kr/wd/155383
# 8700    https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1247596
# Name: 출처 URL, dtype: object

# %%
urls[0]
# Out:
# 'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1252097'

# %%
df.query(f"`출처 URL` == '{urls[idx[15]]}'")
# Out:
#          회사명                          공고명              직무내용  \
# 2920  인그래디언트  [전문연구요원] CV Senior Engineer         C,C++ 개발자
# 4837  인그래디언트  [전문연구요원] CV Senior Engineer         머신러닝 엔지니어
# 5503  인그래디언트  [전문연구요원] CV Senior Engineer  DevOps / 시스템 관리자
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                   자격요건  \
# ...

# %%
df.query(f"`출처 URL` == '{urls[0]}'")
# Out:
#            회사명                                        공고명    직무내용  \
# 8041  (주)퓨처플레이  Backend Developer (FuturePlay Tanagement)  백엔드 개발
#
#                                                                                                                                                                                                                                                                                                                     자격요건  \
# 8041  • AWS에 대한 이해도가 높은 분을 찾습니다. AWS 내부 여러 제품에 대한 이해도가 필요합니다.\r\n• 데이터베이스 설계에 관심있는 분을 찾습니다. 탄탄한 서비스를 위해서, 설계를 끊임없이 연구해야합니다.\r\n• 프론트 개발자들과 적극적인 소통을 하며, 빠르게 대응해줄 수 있는 분을 찾습니다.\r\n• 간단한 스크립트로 사람이 하는 일을 기계가 하도록 효율을 높여본 경험이 있는 분을 찾습니다.\r\n• 지속적인 개발 트렌드를 공부하며, 같이 지식을 나눌 분을 찾습니다. aws, 백엔드, node.js, Docker, typescript
#
#                                                                                                                                                                 우대조건  \
# ...

# %%
idx = []
for i in range(len(urls)):
    if 1 < len(df[df['출처 URL'] == urls[i]]):
        idx.append(i)

# %%
dff = pd.DataFrame(columns = df.columns)

for i in range(len(urls)):
    dff = pd.concat([dff, df.query(f"`출처 URL` == '{urls[i]}'")])

# %%
dff.reset_index(drop = True, inplace = True)

# %%
dff.head(10)
# Out:
#          회사명                                        공고명       직무내용  \
# 0   (주)퓨처플레이  Backend Developer (FuturePlay Tanagement)     백엔드 개발
# 1    (주)인터엑스                        AWS기반 플랫폼 서비스개발자_서울     백엔드 개발
# 2     (주)코드잇                                   백엔드 엔지니어     백엔드 개발
# 3     (주)메디트                                    백엔드 개발자     백엔드 개발
# 4  (주)이랜드이노플                          이랜드몰 JAVA (프레임워크)     백엔드 개발
# 5      메타솔루션                                  프론트엔드 개발자      웹 개발자
# 6      메타솔루션                                  프론트엔드 개발자  프론트엔드 개발자
# 7      메타솔루션                                  프론트엔드 개발자    PHP 개발자
# 8      메타솔루션                                  프론트엔드 개발자      웹 개발자
# 9      메타솔루션                                  프론트엔드 개발자  프론트엔드 개발자
#
# ...

# %%
dff.query(f"`출처 URL` == '{urls[idx[20]]}'")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 dff.query(f"`출처 URL` == '{urls[idx[20]]}'")
#
# IndexError: list index out of range

# %%
dff = dff.drop(index = [14, 15])

# %%
len(dff)
# Out:
# 43

# %%
len(urls)
# Out:
# 44

# %%
dff.reset_index(drop = True, inplace = True)

# %%
dff.to_csv('./sampling_data.csv', encoding = 'utf-8-sig')
