# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/horya/OneDrive/문서/GitHub/Data/찬혁/Data_Pretreatment/Data_result/pre_result.csv')

df.head(1)
# Out:
#      회사명                 공고명  \
# 0  (유)미소  Back-end Developer
#
#                                                 자격요건  \
# 0  [이런 분과 함께하고 싶습니다]\r\n\r\n- 필수 요건 : 백엔드 개발 경력 1...
#
#                                                 우대조건  경력조건  \
# 0  [이런 분이라면 더 좋아요]\r\n\r\n- 대규모 웹 애플리케이션 개발 경험이 있...     3
#
#                                               출처 URL  \
# 0  https://www.jobplanet.co.kr/job/search?posting...
#
#                                                   복지  \
# 0  [보상 및 혜택]\r\n\r\n정직원 Stock Option 보상\r\n월 1회 홈...
#
#                                                 회사소개  \
# 0  Mission\r\n‘We build technology that makes eve...
#
#                                                 주요업무       직무내용
# 0  [미소 프로덕트팀이 일하는 방식]\r\n\r\n1. 문제를 해결하는 엔지니어\r\n...  서버/백엔드 개발

# %% [markdown]
# ### 사전에 선정한 Sample 공고 URL

# %%
urls = ['https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1252097',
        'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1250832',
        'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1249135',
        'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1243455',
        'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1252062',
        'https://www.wanted.co.kr/wd/155658',
        'https://www.wanted.co.kr/wd/155658',
        'https://www.wanted.co.kr/wd/163673',
        'https://www.wanted.co.kr/wd/148349',
        'https://www.wanted.co.kr/wd/167433',
        'https://www.wanted.co.kr/wd/163886',
        'https://www.wanted.co.kr/wd/161960',
        'https://www.wanted.co.kr/wd/161305',
        'https://www.wanted.co.kr/wd/163769',
        'https://www.jumpit.co.kr/position/4204',
        'https://www.jumpit.co.kr/position/4204',
        'https://www.jumpit.co.kr/position/4204',
        'https://www.wanted.co.kr/wd/161585',
        'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1247596',
        'https://www.wanted.co.kr/wd/164601',
        'https://www.wanted.co.kr/wd/97166',
        'https://www.jumpit.co.kr/position/13082',
        'https://www.jumpit.co.kr/position/12965',
        'https://www.wanted.co.kr/wd/161835',
        'https://www.jumpit.co.kr/position/11036',
        'https://www.jumpit.co.kr/position/14411',
        'https://www.wanted.co.kr/wd/161835',
        'https://www.wanted.co.kr/wd/140496',
        'https://www.wanted.co.kr/wd/152935',
        'https://www.wanted.co.kr/wd/160748',
        'https://www.wanted.co.kr/wd/144525',
        'https://www.wanted.co.kr/wd/159587',
        'https://www.wanted.co.kr/wd/158350',
        'https://www.wanted.co.kr/wd/166305',
        'https://www.wanted.co.kr/wd/76590',
        'https://www.wanted.co.kr/wd/155823',
        'https://www.wanted.co.kr/wd/90288',
        'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1252157',
        'https://www.wanted.co.kr/wd/86496',
        'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1248932',
        'https://www.wanted.co.kr/wd/75640',
        'https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1250043',
        'https://www.wanted.co.kr/wd/143022',
        'https://www.wanted.co.kr/wd/163197']

# %% [markdown]
# ### pre_result 중복처리 되기 전에 실행했던 코드입니다 url중복이 되지 않는 공고의 index를 추출하고 중복되는 url에 대한 데이터를 따로 처리하기 위한 코드입니다.

# %%
# idx = []
# for i in range(len(urls)):
#     if 1 < len(df[df['출처 URL'] == urls[i]]):
#         idx.append(i)

# %% [markdown]
# ### Sample 공고의 url과 일치하는 공고만 추출하는 코드입니다.

# %%
dff = pd.DataFrame(columns = df.columns)

for i in range(len(urls)):
    dff = pd.concat([dff, df.query(f"`출처 URL` == '{urls[i]}'")])

# %%
dff.reset_index(drop = True, inplace = True)

# %%
dff.head(10)
# Out:
#          회사명                                        공고명  \
# 0   (주)퓨처플레이  Backend Developer (FuturePlay Tanagement)
# 1    (주)인터엑스                        AWS기반 플랫폼 서비스개발자_서울
# 2     (주)코드잇                                   백엔드 엔지니어
# 3     (주)메디트                                    백엔드 개발자
# 4  (주)이랜드이노플                          이랜드몰 JAVA (프레임워크)
# 5      메타솔루션                                  프론트엔드 개발자
# 6      메타솔루션                                  프론트엔드 개발자
# 7  이지스엔터프라이즈                      프론트엔드 개발자 (VUEJS_주니어)
# 8       리걸테크                  웹개발자(Python, Django) 3년이상
# 9       혜움랩스                            프론트엔드 개발자 (주니어)
#
#                                                 자격요건  \
# 0  • AWS에 대한 이해도가 높은 분을 찾습니다. AWS 내부 여러 제품에 대한 이해...
# 1  [이런 분이 필요해요!]\r\n• AWS 운영 경험\r\n• AWS 관련 자격증 보...
# 2  • 2년 이상의 백엔드 개발 경험이 있는 분\r\n• 알고리즘과 자료구조에 대한 이...
# 3  • 백엔드 개발 경력 5년 이상 또는 그에 상응하는 역량을 가지신 분\r\n• Sp...
# 4  • Spring framework (SpringBoot) 경력 10년 이상\r\n•...
# 5  • 포항 출퇴근 가능자\r\n• HTML, CSS, javascript, Ajax ...
# 6  • 포항 출퇴근 가능자\r\n• HTML, CSS, javascript, Ajax ...
# 7  - 기본 기술 자격 요건\r\n   • Vue.js 개발 업무를 2년 이상 경험하신...
# 8  • 웹서비스 개발 3년 이상 유 경험자\r\n• Python, DJango를 기반으...
# 9  • HTML / CSS / JavaScript 에 대한 이해\r\n• 컴퓨터 사이언...
#
#                                                 우대조건 경력조건  \
# 0  • 컴퓨터 공학에 대한 기본기가 탄탄한 분이면 좋습니다.\r\n• Domain Dr...    0
# 1  [이런 분이면 더욱 좋아요!]\r\n• AWS SA 자격증 보유\r\n• 유저가 겪...    3
# 2  • 컴퓨터 과학과 또는 컴퓨터 공학과 출신자\r\n• 코드잇의 개발 스택(주요 업무...    2
# 3  • eCommerce 시스템 설계 및 운영 경험이 있으신 분\r\n• 병원, 의료 ...    5
# 4  • 이커머스 개발 경험\r\n• AWS/GCP등 클라우드 경험\r\n• 고성능, 대...   10
# 5  • VUE.JS / REACT.JS 개발 경험자\r\n• GRID 형태의 관리자 웹...    0
# 6  • VUE.JS / REACT.JS 개발 경험자\r\n• GRID 형태의 관리자 웹...    0
# 7  - 보유 기술 우대사항\r\n • Vue.js + Spring Boot 연동 개발 ...    2
# 8                        • 일본어 가능\r\n• 블록체인 기본 지식 보유    3
# 9  • Vue.js, React.js, Angular 등 SPA 개발 경험이 있는 분\...    0
#
#                                               출처 URL  \
# 0  https://www.jobplanet.co.kr/job/search?posting...
# 1  https://www.jobplanet.co.kr/job/search?posting...
# 2  https://www.jobplanet.co.kr/job/search?posting...
# 3  https://www.jobplanet.co.kr/job/search?posting...
# 4  https://www.jobplanet.co.kr/job/search?posting...
# 5                 https://www.wanted.co.kr/wd/155658
# 6                 https://www.wanted.co.kr/wd/155658
# 7                 https://www.wanted.co.kr/wd/163673
# 8                 https://www.wanted.co.kr/wd/148349
# 9                 https://www.wanted.co.kr/wd/167433
#
#                                                   복지  \
# 0  [복리후생]\r\n1. 더 나은 사람과 회사가 되도록 고민합니다\r\n• 직무의 성...
# 1  항시 음악이 흐르는 쾌적한 오피스공간\r\n• 사내 카페테리아 운영 중 (커피, 음...
# 2  1. 최고의 팀원에게 최고의 보상을 제공해요.\r\n• 최고의 동료들이 모인 팀\r...
# 3  [복지]\r\n1. 근무 환경\r\n- 유연근무제\r\n- 수평적인 호칭 체계\r\...
# 4  [근무환경]\r\n• 시차 출퇴근제 운영\r\n - 7-10시 사이, 내가 가장 몰...
# 5  • 4대보험(국민연금,건강보험,고용보험,산재보험) 가입\r\n• 카페테리아,주차장 ...
# 6  • 4대보험(국민연금,건강보험,고용보험,산재보험) 가입\r\n• 카페테리아,주차장 ...
# 7  [건강한 사내문화]\r\n• 탄력 근무제, 자유로운 연차, 회식 강요 안해요\r\n...
# 8  • 주 5일제 근무\r\n• 2호선 뚝섬역 4번출구 200m의 접근성\r\n•명절 ...
# 9  # 몰입을 위한\r\n• 액면가 스톡옵션의 기회가 열려있습니다. (2023년 7월 ...
#
#                                                 회사소개  \
# 0  FuturePlay의 미션은 "10년 안의 미래를 바라보며, 장기적 관점에서 초기 ...
# 1  인터엑스는 '세계 최고의 제조AI 및 자율공장 전문 파트너' 입니다.\r\n\r\n...
# 2                   ★ 2023 코드잇 인재 채용: 전 직군 스톡옵션 제공 ★
# 3  Fulfill Your Potential!\r\n\r\n메디트(Medit)에서 글로...
# 4  [이랜드이노플 소개]\r\n이랜드이노플은 '누구에게나 쉽고 편한 IT 서비스를 제공...
# 5  Meta Solution은 IT 기술을 활용하여 철강산업 분야의 안전성과 효율성을 ...
# 6  Meta Solution은 IT 기술을 활용하여 철강산업 분야의 안전성과 효율성을 ...
# 7  * 압도적인 안정성과 시장 점유율 1위인 저희 이지스엔터프라이즈와 함께 성장하실 분...
# 8  [회사소개]\r\n\r\n리걸테크㈜는 2015년 설립 이후 클라우드,블록체인, 빅데...
# 9  - 간단소개\r\n혜움랩스는 세무,재무,경리 등 AI기반 비서형 금융 서비스를 Fa...
#
#                                                 주요업무                  직무내용
# 0  • 태니지먼트 서비스의 백엔드 및 AWS Infra를 개발, 관리합니다.\r\n• ...             서버/백엔드 개발
# 1  [함께하시면 맡게 될 업무입니다!]\r\n• AWS를 활용한 솔루션 구축 및 운영\...             서버/백엔드 개발
# 2  【 이런 팀에서 일해요 】\r\n코드잇은 본질적인 프로덕트의 발전이 반드시 뒷받침 ...             서버/백엔드 개발
# 3  • 서비스 목적 및 고객 요구사항에 기반한 아키텍처 설계, 개발\r\n• 더 나은 ...             서버/백엔드 개발
# 4  • 이랜드몰(e-commerce 플랫폼) 서비스 백엔드 개발 및 운영\r\n• Re...             서버/백엔드 개발
# 5                    • 어플리케이션 / 어드민 개발\r\n• 서비스 유지보수  웹개발,프론트엔드 개발,PHP 개발자
# 6                    • 어플리케이션 / 어드민 개발\r\n• 서비스 유지보수  웹개발,프론트엔드 개발,PHP 개발자
# 7  • 이지스엔터프라이즈에서 제공하는 공동주택, 집합건물 관리 어플리케이션을 개발하고 ...          웹개발,프론트엔드 개발
# 8  블록체인 기술을 기반으로 하는 기존 서비스의 기능 추가및 리팩토링\r\n\r\n[채...           웹개발,파이썬 개발자
# 9  • 세무 관련 서비스 및 플랫폼의 프론트엔드 에플리케이션 개발\r\n• 요구사항 분...   웹개발,프론트엔드 개발,자바 개발자

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   회사명     39 non-null     object
#  1   공고명     39 non-null     object
#  2   자격요건    39 non-null     object
#  3   우대조건    39 non-null     object
#  4   경력조건    39 non-null     object
#  5   출처 URL  39 non-null     object
#  6   복지      39 non-null     object
#  7   회사소개    39 non-null     object
#  8   주요업무    39 non-null     object
#  9   직무내용    39 non-null     object
# dtypes: object(10)
# memory usage: 3.2+ KB

# %%
dff.reset_index(drop = True, inplace = True)

# %%
dff.head()
# Out:
#          회사명                                        공고명  \
# 0   (주)퓨처플레이  Backend Developer (FuturePlay Tanagement)
# 1    (주)인터엑스                        AWS기반 플랫폼 서비스개발자_서울
# 2     (주)코드잇                                   백엔드 엔지니어
# 3     (주)메디트                                    백엔드 개발자
# 4  (주)이랜드이노플                          이랜드몰 JAVA (프레임워크)
#
#                                                 자격요건  \
# 0  • AWS에 대한 이해도가 높은 분을 찾습니다. AWS 내부 여러 제품에 대한 이해...
# 1  [이런 분이 필요해요!]\r\n• AWS 운영 경험\r\n• AWS 관련 자격증 보...
# 2  • 2년 이상의 백엔드 개발 경험이 있는 분\r\n• 알고리즘과 자료구조에 대한 이...
# 3  • 백엔드 개발 경력 5년 이상 또는 그에 상응하는 역량을 가지신 분\r\n• Sp...
# 4  • Spring framework (SpringBoot) 경력 10년 이상\r\n•...
#
#                                                 우대조건 경력조건  \
# 0  • 컴퓨터 공학에 대한 기본기가 탄탄한 분이면 좋습니다.\r\n• Domain Dr...    0
# 1  [이런 분이면 더욱 좋아요!]\r\n• AWS SA 자격증 보유\r\n• 유저가 겪...    3
# 2  • 컴퓨터 과학과 또는 컴퓨터 공학과 출신자\r\n• 코드잇의 개발 스택(주요 업무...    2
# 3  • eCommerce 시스템 설계 및 운영 경험이 있으신 분\r\n• 병원, 의료 ...    5
# 4  • 이커머스 개발 경험\r\n• AWS/GCP등 클라우드 경험\r\n• 고성능, 대...   10
#
#                                               출처 URL  \
# 0  https://www.jobplanet.co.kr/job/search?posting...
# 1  https://www.jobplanet.co.kr/job/search?posting...
# 2  https://www.jobplanet.co.kr/job/search?posting...
# 3  https://www.jobplanet.co.kr/job/search?posting...
# 4  https://www.jobplanet.co.kr/job/search?posting...
#
#                                                   복지  \
# 0  [복리후생]\r\n1. 더 나은 사람과 회사가 되도록 고민합니다\r\n• 직무의 성...
# 1  항시 음악이 흐르는 쾌적한 오피스공간\r\n• 사내 카페테리아 운영 중 (커피, 음...
# 2  1. 최고의 팀원에게 최고의 보상을 제공해요.\r\n• 최고의 동료들이 모인 팀\r...
# 3  [복지]\r\n1. 근무 환경\r\n- 유연근무제\r\n- 수평적인 호칭 체계\r\...
# 4  [근무환경]\r\n• 시차 출퇴근제 운영\r\n - 7-10시 사이, 내가 가장 몰...
#
#                                                 회사소개  \
# 0  FuturePlay의 미션은 "10년 안의 미래를 바라보며, 장기적 관점에서 초기 ...
# 1  인터엑스는 '세계 최고의 제조AI 및 자율공장 전문 파트너' 입니다.\r\n\r\n...
# 2                   ★ 2023 코드잇 인재 채용: 전 직군 스톡옵션 제공 ★
# 3  Fulfill Your Potential!\r\n\r\n메디트(Medit)에서 글로...
# 4  [이랜드이노플 소개]\r\n이랜드이노플은 '누구에게나 쉽고 편한 IT 서비스를 제공...
#
#                                                 주요업무       직무내용
# 0  • 태니지먼트 서비스의 백엔드 및 AWS Infra를 개발, 관리합니다.\r\n• ...  서버/백엔드 개발
# 1  [함께하시면 맡게 될 업무입니다!]\r\n• AWS를 활용한 솔루션 구축 및 운영\...  서버/백엔드 개발
# 2  【 이런 팀에서 일해요 】\r\n코드잇은 본질적인 프로덕트의 발전이 반드시 뒷받침 ...  서버/백엔드 개발
# 3  • 서비스 목적 및 고객 요구사항에 기반한 아키텍처 설계, 개발\r\n• 더 나은 ...  서버/백엔드 개발
# 4  • 이랜드몰(e-commerce 플랫폼) 서비스 백엔드 개발 및 운영\r\n• Re...  서버/백엔드 개발

# %%
dff.to_csv('./sampling_data.csv', encoding = 'utf-8-sig')
